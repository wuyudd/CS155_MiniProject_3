# %% [markdown]
# # Problem 2

# %% [markdown]
# In this Jupyter notebook, we visualize how HMMs work. This visualization corresponds to problem 2 in set 6.
#
# Assuming your HMM module is complete and saved at the correct location, you can simply run all cells in the notebook without modification.

# %%
import os
import numpy as np
from IPython.display import HTML

from HMM import unsupervised_HMM
from HMM_helper import (
    text_to_wordcloud,
    states_to_wordclouds,
    parse_observations,
    sample_sentence,
    visualize_sparsities,
    animate_emission
)

# %% [markdown]
# ## Visualization of the dataset

# %% [markdown]
# We will be using the Constitution as our dataset. First, we visualize the entirety of the Constitution as a wordcloud:

# %%
text = open(os.path.join(os.getcwd(), 'data/constitution.txt')).read()
wordcloud = text_to_wordcloud(text, title='Constitution')

# %% [markdown]
# ## Training an HMM

# %% [markdown]
# Now we train an HMM on our dataset. We use 10 hidden states and train over 100 iterations:

# %%
obs, obs_map = parse_observations(text)
print(obs_map)
# Out:
# {'we': 0, 'the': 1, 'people': 2, 'of': 3, 'united': 4, 'states': 5, 'in': 6, 'order': 7, 'to': 8, 'form': 9, 'a': 10, 'more': 11, 'perfect': 12, 'union': 13, 'establish': 14, 'justice': 15, 'insure': 16, 'domestic': 17, 'tranquility': 18, 'provide': 19, 'for': 20, 'common': 21, 'defence': 22, 'promote': 23, 'general': 24, 'welfare': 25, 'and': 26, 'secure': 27, 'blessings': 28, 'liberty': 29, 'ourselves': 30, 'our': 31, 'posterity': 32, 'do': 33, 'ordain': 34, 'this': 35, 'constitution': 36, 'america': 37, 'article': 38, 'i': 39, 'section': 40, '1': 41, 'all': 42, 'legislative': 43, 'powers': 44, 'herein': 45, 'granted': 46, 'shall': 47, 'be': 48, 'vested': 49, 'congress': 50, 'which': 51, 'consist': 52, 'senate': 53, 'house': 54, 'representatives': 55, '2': 56, 'composed': 57, 'members': 58, 'chosen': 59, 'every': 60, 'second': 61, 'year': 62, 'by': 63, 'several': 64, 'electors': 65, 'each': 66, 'state': 67, 'have': 68, 'qualifications': 69, 'requisite': 70, 'most': 71, 'numerous': 72, 'branch': 73, 'legislature': 74, 'no': 75, 'person': 76, 'representative': 77, 'who': 78, 'not': 79, 'attained': 80, 'age': 81, 'twenty': 82, 'five': 83, 'years': 84, 'been': 85, 'seven': 86, 'citizen': 87, 'when': 88, 'elected': 89, 'an': 90, 'inhabitant': 91, 'that': 92, 'he': 93, 'direct': 94, 'taxes': 95, 'apportioned': 96, 'among': 97, 'may': 98, 'included': 99, 'within': 100, 'according': 101, 'their': 102, 'respective': 103, 'numbers': 104, 'determined': 105, 'adding': 106, 'whole': 107, 'number': 108, 'free': 109, 'persons': 110, 'including': 111, 'those': 112, 'bound': 113, 'service': 114, 'term': 115, 'excluding': 116, 'indians': 117, 'taxed': 118, 'three': 119, 'fifths': 120, 'other': 121, 'actual': 122, 'enumeration': 123, 'made': 124, 'after': 125, 'first': 126, 'meeting': 127, 'subsequent': 128, 'ten': 129, 'such': 130, 'manner': 131, 'as': 132, 'they': 133, 'law': 134, 'exceed': 135, 'one': 136, 'thirty': 137, 'thousand': 138, 'but': 139, 'at': 140, 'least': 141, 'until': 142, 'new': 143, 'hampshire': 144, 'entitled': 145, 'chuse': 146, 'massachusetts': 147, 'eight': 148, 'rhodeisland': 149, 'providence': 150, 'plantations': 151, 'connecticut': 152, 'newyork': 153, 'six': 154, 'jersey': 155, 'four': 156, 'pennsylvania': 157, 'delaware': 158, 'maryland': 159, 'virginia': 160, 'north': 161, 'carolina': 162, 'south': 163, 'georgia': 164, 'vacancies': 165, 'happen': 166, 'representation': 167, 'from': 168, 'any': 169, 'executive': 170, 'authority': 171, 'thereof': 172, 'issue': 173, 'writs': 174, 'election': 175, 'fill': 176, 'speaker': 177, 'officers': 178, 'sole': 179, 'power': 180, 'impeachment': 181, '3': 182, 'two': 183, 'senators': 184, 'senator': 185, 'vote': 186, 'immediately': 187, 'assembled': 188, 'consequence': 189, 'divided': 190, 'equally': 191, 'into': 192, 'classes': 193, 'seats': 194, 'class': 195, 'vacated': 196, 'expiration': 197, 'fourth': 198, 'third': 199, 'sixth': 200, 'so': 201, 'if': 202, 'resignation': 203, 'or': 204, 'otherwise': 205, 'during': 206, 'recess': 207, 'make': 208, 'temporary': 209, 'appointments': 210, 'next': 211, 'then': 212, 'nine': 213, 'vice': 214, 'president': 215, 'unless': 216, 'also': 217, 'pro': 218, 'tempore': 219, 'absence': 220, 'exercise': 221, 'office': 222, 'try': 223, 'impeachments': 224, 'sitting': 225, 'purpose': 226, 'on': 227, 'oath': 228, 'affirmation': 229, 'is': 230, 'tried': 231, 'chief': 232, 'preside': 233, 'convicted': 234, 'without': 235, 'concurrence': 236, 'thirds': 237, 'present': 238, 'judgment': 239, 'cases': 240, 'extend': 241, 'further': 242, 'than': 243, 'removal': 244, 'disqualification': 245, 'hold': 246, 'enjoy': 247, 'honor': 248, 'trust': 249, 'profit': 250, 'under': 251, 'party': 252, 'nevertheless': 253, 'liable': 254, 'subject': 255, 'indictment': 256, 'trial': 257, 'punishment': 258, '4': 259, 'times': 260, 'places': 261, 'holding': 262, 'elections': 263, 'prescribed': 264, 'time': 265, 'alter': 266, 'regulations': 267, 'except': 268, 'chusing': 269 ...

# %%
hmm8 = unsupervised_HMM(obs, 10, 100)

# %% [markdown]
# ## Part G: Visualization of the sparsities of A and O

# %% [markdown]
# We can visualize the sparsities of the A and O matrices by treating the matrix entries as intensity values and showing them as images. What patterns do you notice?

# %%
visualize_sparsities(hmm8, O_max_cols=50)

# %% [markdown]
# ## Generating a sample sentence

# %% [markdown]
# As you have already seen, an HMM can be used to generate sample sequences based on the given dataset. Run the cell below to show a sample sentence based on the Constitution.

# %%
print('Sample Sentence:\n====================')
print(sample_sentence(hmm8, obs_map, n_words=25))
# Out:
# Sample Sentence:
# ====================
# General house and not be for when or make such states of when or as elected the united president with for each subject and the...

# %% [markdown]
# ## Part H: Using varying numbers of hidden states

# %% [markdown]
# Using different numbers of hidden states can lead to different behaviours in the HMMs. Below, we train several HMMs with 1, 2, 4, and 16 hidden states, respectively. What do you notice about their emissions? How do these emissions compare to the emission above?

# %%
hmm1 = unsupervised_HMM(obs, 1, 100)
print('\nSample Sentence:\n====================')
print(sample_sentence(hmm1, obs_map, n_words=25))
# Out:
# Sample Sentence:
# ====================
# Regulate or state parts laws on houses third the nine if states be any death of or be any work erazure states on of a...

# %%
hmm2 = unsupervised_HMM(obs, 2, 100)
print('\nSample Sentence:\n====================')
print(sample_sentence(hmm2, obs_map, n_words=25))
# Out:
# Sample Sentence:
# ====================
# Citizen the to directed compensation six of have of adjournment execute the names treaties congress and representative the respecting vested the have which of of...

# %%
hmm4 = unsupervised_HMM(obs, 4, 100)
print('\nSample Sentence:\n====================')
print(sample_sentence(hmm4, obs_map, n_words=25))
# Out:
# Sample Sentence:
# ====================
# As united day an partly in try kind appointed like shall so they peace thereof law follows the within a executive in united the section...

# %%
hmm16 = unsupervised_HMM(obs, 16, 100)
print('\nSample Sentence:\n====================')
print(sample_sentence(hmm16, obs_map, n_words=25))
# Out:
# Sample Sentence:
# ====================
# He both issue at representatives thirds which discharge the choice state otherwise the senate state under blood sealed of guarantee by and to the united...

# %% [markdown]
# ## Part I: Visualizing the wordcloud of each state

# %% [markdown]
# Below, we visualize each state as a wordcloud by sampling a large emission from the state:

# %%
wordclouds = states_to_wordclouds(hmm8, obs_map)

# %% [markdown]
# ## Visualizing the process of an HMM generating an emission

# %% [markdown]
# The visualization below shows how an HMM generates an emission. Each state is shown as a wordcloud on the plot, and transition probabilities between the states are shown as arrows. The darker an arrow, the higher the transition probability.
#
# At every frame, a transition is taken and an observation is emitted from the new state. A red arrow indicates that the transition was just taken. If a transition stays at the same state, it is represented as an arrowhead on top of that state.
#
# Use fullscreen for a better view of the process.

# %%
anim = animate_emission(hmm8, obs_map, M=8)
HTML(anim.to_html5_video())
# Out:
# /Users/ywwu/anaconda3/envs/python3_6/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "
# Animating...
# <video width="864" height="864" controls autoplay loop>
#   <source type="video/mp4" src="...
